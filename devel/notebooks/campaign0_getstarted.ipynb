# %%
# import pre-requesite
import os
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg

# %%
# Get image from sample and show
img_folder = '../imgsamples/'
os.listdir(img_folder)
img1 = mpimg.imread(os.path.join(img_folder,os.listdir(img_folder)[0]))
img2 = mpimg.imread(os.path.join(img_folder,os.listdir(img_folder)[1]))
plt.imshow(img1)
plt.show()
